# %%
#Task1:Design caluclators using oops concept
class Calculator:
    def __init__(self):
        print("Calculator")
    def add(self, a, b):
        return a + b
    def sub(self, a, b):
        return a - b
    def multiply(self, a, b):
        return a * b
    def divide(self, a, b):
        if b == 0:   
            return "Error! Division by zero."
        return a / b
cal = Calculator()
print("Addition:", cal.add(20, 4))
print("Subtraction:", cal.sub(20, 4))
print("Multiplication:", cal.multiply(20, 4))
print("Division:", cal.divide(20, 4))
# Out:
# Calculator
# Addition: 24
# Subtraction: 16
# Multiplication: 80
# Division: 5.0

# %%
# Task2: i) Multiple Inheritance
class Father:
    def skills(self):
        print("Father: Gardening, Carpentry")
class Mother:
    def skills(self):
        print("Mother: Cooking, Painting")
class Child(Father, Mother):  
    def skills(self):
        print("Child: Coding, Sports")
        Father.skills(self)
        Mother.skills(self)
c = Child()
c.skills()
# Out:
# Child: Coding, Sports
# Father: Gardening, Carpentry
# Mother: Cooking, Painting

# %%
# ii) Multilevel Inheritance
class Grandparent:
    def property(self):
        print("Grandparent: Land")
class Parent(Grandparent):
    def money(self):
        print("Parent: House & Savings")
class Child(Parent):
    def hobby(self):
        print("Child: Reading & Gaming")

c = Child()
c.property()
c.money()
c.hobby()
# Out:
# Grandparent: Land
# Parent: House & Savings
# Child: Reading & Gaming

# %%
# iii) Hierarchical Inheritance
class Animal:
    def sound(self):
        print("Animals make sounds")
class Dog(Animal):
    def sound(self):
        print("Dog barks")
class Cat(Animal):
    def sound(self):
        print("Cat meows")
d = Dog()
c = Cat()
d.sound()
c.sound()
# Out:
# Dog barks
# Cat meows

# %%
# iv) Hybrid Inheritance
class School:
    def show(self):
        print("This is a school")
class Teacher(School):
    def teach(self):
        print("Teacher teaches subjects")
class Student(School):
    def learn(self):
        print("Student learns lessons")
class Monitor(Teacher, Student):  
    def duty(self):
        print("Monitor maintains discipline")
m = Monitor()
m.show()
m.teach()
m.learn()
m.duty()
# Out:
# This is a school
# Teacher teaches subjects
# Student learns lessons
# Monitor maintains discipline

# %%
# Task3: i)Method Overriding
class Parent:
    def show(self):
        print("Parent class method")
class Child(Parent):
    def show(self):  
        print("Child class method")
c = Child()
c.show()
# Out:
# Child class method

# %%
#ii) Method Overloading with default arguments
class Calculator:
    def add(self, a, b=0, c=0):
        return a + b + c
cal = Calculator()
print("Sum of 2 numbers:", cal.add(10, 20))
print("Sum of 3 numbers:", cal.add(10, 20, 30))
# Out:
# Sum of 2 numbers: 30
# Sum of 3 numbers: 60

# %%
# Method Overloading using *args
class Calculator:
    def add(self, *args):
        return sum(args)
cal = Calculator()
print("Sum of 2 numbers:", cal.add(10, 20))
print("Sum of 3 numbers:", cal.add(10, 20, 30))
print("Sum of 4 numbers:", cal.add(10, 20, 30, 40))
# Out:
# Sum of 2 numbers: 30
# Sum of 3 numbers: 60
# Sum of 4 numbers: 100

# %%
#streamelit
